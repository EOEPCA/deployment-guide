# %% [markdown]
# # EOEPCA Resource Health Validation and Usage Notebook

# %% [markdown]
# ## Introduction
#
# The **Resource Health Building Block** monitors the health and status of resources across an EOEPCA platform: core platform services as well as user-provided resources such as datasets, workflows or applications.
#
# This notebook walks through the main path: authenticate, explore the available check templates, register a health check, trigger it, and confirm the result lands in the telemetry backend.

# %% [markdown]
# ## Setup

# %%
import os
import requests
import json
from time import time, sleep

import sys
sys.path.append('../')
from modules.helpers import get_access_token, load_eoepca_state, test_cell, test_results

# %% [markdown]
# Load `eoepca state` environment

# %%
load_eoepca_state()

# %%
platform_domain = os.environ["INGRESS_HOST"]
http_scheme = os.environ.get("HTTP_SCHEME", "https")
resource_health_domain = f"{http_scheme}://resource-health.{platform_domain}"

resource_health_enable_oidc = os.environ.get("RESOURCE_HEALTH_ENABLE_OIDC", "no") == "yes"

log_output_file = "resource-health_log.json"

# %%
# If you have a self-signed CA certificate for your cluster then this can be useful to avoid TLS errors below.
os.environ["REQUESTS_CA_BUNDLE"] = "/etc/ssl/certs/ca-certificates.crt"
verify_tls = True

print(f"Resource Health URL: {resource_health_domain}")
print(f"OIDC protection enabled: {resource_health_enable_oidc}")

# %% [markdown]
# ## Authentication
#
# The reference deployment protects Resource Health with OIDC at the APISIX ingress layer (`ApisixRoute` + `openid-connect` plugin) - there is no NGINX equivalent, so `RESOURCE_HEALTH_ENABLE_OIDC=yes` requires `INGRESS_CLASS=apisix`. With OIDC disabled, every endpoint below is reachable without a token.

# %%
def get_auth_headers():
    """Authentication headers for Resource Health API requests, if OIDC is enabled."""
    if not resource_health_enable_oidc:
        return {"Content-Type": "application/vnd.api+json"}
    token = get_access_token(
        username=os.environ["KEYCLOAK_TEST_USER"],
        password=os.environ["KEYCLOAK_TEST_PASSWORD"],
        client_id=os.environ.get("RESOURCE_HEALTH_CLIENT_ID", "resource-health"),
        client_secret=os.environ["RESOURCE_HEALTH_CLIENT_SECRET"],
    )
    return {"Authorization": f"Bearer {token}", "Content-Type": "application/vnd.api+json"}

auth_headers = get_auth_headers()
print("Access token acquired." if resource_health_enable_oidc else "OIDC disabled - no token needed.")

# %% [markdown]
# ## Validate Resource Health Endpoints

# %%
# endpoints_healthy
endpoints = [
    ("Health Checks API docs", f"{resource_health_domain}/api/healthchecks/docs"),
    ("Telemetry API docs", f"{resource_health_domain}/api/telemetry/docs"),
    ("Check templates", f"{resource_health_domain}/api/healthchecks/v1/check_templates/"),
    ("Checks list", f"{resource_health_domain}/api/healthchecks/v1/checks/"),
]

for name, url in endpoints:
    response = requests.get(url, headers=auth_headers, verify=verify_tls, timeout=10)
    print(f"{response.status_code} {name}")
    assert response.status_code == 200, f"{name} returned {response.status_code}"

# %% [markdown]
# ## Health Check Templates
#
# Templates define reusable patterns for common monitoring scenarios. The default deployment includes:
#
# - **simple_ping** - checks an endpoint responds with an expected HTTP status code.
# - **generic_script_template** - runs a custom pytest script from a URL.
# - **telemetry_access_template** - runs a userscript with access to the telemetry API.

# %%
templates_url = f"{resource_health_domain}/api/healthchecks/v1/check_templates/"
response = requests.get(templates_url, headers=auth_headers, verify=verify_tls)
response.raise_for_status()

templates = response.json()["data"]
for template in templates:
    metadata = template["attributes"]["metadata"]
    print(f"{template['id']}: {metadata['description']}")

# %%
# Look at the simple_ping template's argument schema in detail.
detail_url = f"{resource_health_domain}/api/healthchecks/v1/check_templates/simple_ping"
response = requests.get(detail_url, headers=auth_headers, verify=verify_tls)
response.raise_for_status()

print(json.dumps(response.json()["data"]["attributes"]["arguments"], indent=2))

# %% [markdown]
# ## Create a Health Check
#
# The Resource Health API uses [JSON:API](https://jsonapi.org/) format. This registers a `simple_ping` check against the bundled Mock API (an in-cluster demo target, reachable at `resource-health-mock-api:5000` from the check runner - real checks would typically target a real endpoint instead).

# %%
# create_check
checks_url = f"{resource_health_domain}/api/healthchecks/v1/checks/"
check_payload = {
    "data": {
        "type": "check",
        "attributes": {
            # A schedule far in the future - this check is run on demand
            # below rather than waiting for its own trigger, and a rarely
            # firing schedule avoids a coincidental scheduled run landing
            # mid-notebook and confusing the result check further down.
            "schedule": "0 0 1 1 *",
            "metadata": {
                "name": "notebook-ping-check",
                "description": "Notebook usage example - checks the bundled Mock API is reachable",
                "template_id": "simple_ping",
                "template_args": {
                    "endpoint": "http://resource-health-mock-api:5000/",
                    "expected_status_code": 200,
                },
            },
        },
    }
}

response = requests.post(checks_url, headers=auth_headers, json=check_payload, verify=verify_tls)
assert response.status_code == 201, response.text

check_id = response.json()["data"]["id"]
print(f"Created check: {check_id}")

# %%
# check_appears_in_list
response = requests.get(checks_url, headers=auth_headers, verify=verify_tls)
response.raise_for_status()

check_ids = [check["id"] for check in response.json()["data"]]
print(f"{len(check_ids)} check(s) registered")
assert check_id in check_ids

# %% [markdown]
# ## Trigger the Check and View Results
#
# Rather than waiting for the schedule, the check can be run immediately. Results are exported as OpenTelemetry traces, stored in OpenSearch, and queryable via the Telemetry API - the same pipeline the web dashboard uses.

# %%
# trigger_check_run
run_url = f"{resource_health_domain}/api/healthchecks/v1/checks/{check_id}/run/"
response = requests.post(run_url, headers=auth_headers, verify=verify_tls)
assert response.status_code == 204, response.text
print("Run triggered.")

# %%
# check_result_recorded
# Telemetry export happens asynchronously once the check's Job pod completes -
# poll with a bounded timeout rather than a fixed sleep.
spans_url = f"{resource_health_domain}/api/telemetry/v1/spans"
result_status = None
latest_start_time = -1
deadline = time() + 120

while time() < deadline and result_status is None:
    response = requests.get(
        spans_url,
        headers=auth_headers,
        params={"resource_attributes": f'k8s.cronjob.name="{check_id}"'},
        verify=verify_tls,
    )
    response.raise_for_status()
    for record in response.json()["data"]:
        for resource_span in record["attributes"]["resourceSpans"]:
            for scope in resource_span["scopeSpans"]:
                for span in scope["spans"]:
                    attrs = {a["key"]: list(a["value"].values())[0] for a in span["attributes"]}
                    start_time = int(span["startTimeUnixNano"])
                    if "test.case.result.status" in attrs and start_time > latest_start_time:
                        latest_start_time = start_time
                        result_status = attrs["test.case.result.status"]
    if result_status is None:
        sleep(5)

print(f"Result status: {result_status}")
assert result_status == "pass", f"No passing result recorded within timeout (got: {result_status})"

# %% [markdown]
# ## Delete the Health Check

# %%
# delete_check
delete_url = f"{resource_health_domain}/api/healthchecks/v1/checks/{check_id}"
response = requests.delete(delete_url, headers=auth_headers, verify=verify_tls)
assert response.status_code in (200, 204), response.text

response = requests.get(checks_url, headers=auth_headers, verify=verify_tls)
response.raise_for_status()
remaining_ids = [check["id"] for check in response.json()["data"]]
assert check_id not in remaining_ids
print("Check deleted.")

# %% [markdown]
# ## Web Dashboard
#
# Visit `{resource_health_domain}` for a graphical view of registered checks, their schedules and recent results. New checks can also be created directly from the dashboard by selecting a template and filling in its arguments - the same JSON:API calls made above happen behind the UI.
#
# ## Further Reading
#
# - [Resource Health GitHub Repository](https://github.com/EOEPCA/resource-health)

# %%
if test_results:
    for test, result in test_results.items():
        print(f"{test}: {result['status']} - {result['message']}")
    json.dump(test_results, open(log_output_file, "w"), indent=2)
