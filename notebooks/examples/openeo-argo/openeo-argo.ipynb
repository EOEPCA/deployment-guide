# %% [markdown]
# # openEO ArgoWorkflows Demonstration

# %% [markdown]
# ## Setup

# %%
import os
import openeo
import json
import time
import xarray
import matplotlib.pyplot as pyplot
from IPython.display import display, Markdown

import sys
sys.path.append('../')
from modules.helpers import get_access_token, load_eoepca_state, test_cell, test_results

# %% [markdown]
# Load `eoepca state` environment

# %%
load_eoepca_state()

# %%
platform_domain = os.environ.get("INGRESS_HOST")

openeo_backend = f"openeo.{platform_domain}"
stac_api_url = f"https://eoapi.{platform_domain}/stac"

username = os.environ.get("KEYCLOAK_TEST_USER")
password = os.environ.get("KEYCLOAK_TEST_PASSWORD")
client_id = "openeo-argo"

collection_id = "sentinel-2-iceland"
temporal_extent = ["2023-11-09", "2023-11-10"]
spatial_extent = {"west": -24.9, "south": 64.2, "east": -24.5, "north": 64.5}

log_output_file = "openeo_argo_log.json"

# %%
print(f"Parameters:\n"
f"Platform domain: {platform_domain}\n"
f"OpenEO backend: {openeo_backend}\n"
f"STAC API URL: {stac_api_url}\n"
f"Client ID: {client_id}\n"
f"Collection ID: {collection_id}\n"
f"Temporal extent: {temporal_extent}\n"
f"Spatial extent: {spatial_extent}")
# Out:
# Parameters:
# Platform domain: test.eoepca.org
# OpenEO backend: openeo.test.eoepca.org
# STAC API URL: https://eoapi.test.eoepca.org/stac
# Client ID: openeo-argo
# Collection ID: sentinel-2-iceland
# Temporal extent: ['2023-11-09', '2023-11-10']
# Spatial extent: {'west': -24.9, 'south': 64.2, 'east': -24.5, 'north': 64.5}

# %% [markdown]
# ## Connect to the openEO ArgoWorkflows backend

# %%
connection = openeo.connect(url=openeo_backend)

# Authenticate using OIDC access token
access_token = get_access_token(username, password, client_id)
auth_token = f"oidc/eoepca/{access_token}"
connection.session.headers.update({"Authorization": f"Bearer {auth_token}"})

# %% [markdown]
# ## Exploration

# %% [markdown]
# Available collections:

# %%
# collection_exists
available_collections = connection.list_collection_ids()
print(f"Available collections: {available_collections}")
assert collection_id in available_collections
# Out:
# Available collections: ['datacube-ready-collection', 'noaa-emergency-response', 'sentinel-2-datacube', 'sentinel-2-iceland', 'sentinel-2-l2a-datacube']

# %% [markdown]
# Collection details:

# %%
collection_info = connection.describe_collection(collection_id)
print(f"Collection: {collection_info.get('id')}")
print(f"Description: {collection_info.get('description', 'N/A')}")
print("\nAvailable bands:")
for band in collection_info.get("summaries", {}).get("eo:bands", []):
    print(f"  - {band.get('name')}: {band.get('common_name', 'N/A')}")
# Out:
# Collection: sentinel-2-iceland
# Description: Sentinel-2 data from 2023 over Iceland.
#
# Available bands:
#   - coastal: coastal
#   - blue: blue
#   - green: green
#   - red: red
#   - rededge1: rededge
#   - rededge2: rededge
#   - rededge3: rededge
#   - nir: nir
#   - nir08: nir08
#   - nir09: nir09
#   - cirrus: cirrus
#   - swir16: swir16
#   - swir22: swir22

# %% [markdown]
# Available processes:

# %%
# list_processes
[p["id"] for p in connection.list_processes()[:10]]
# Out:
# ['all',
#  'pi',
#  'not',
#  'apply',
#  'array_apply',
#  'sar_backscatter',
#  'arccos',
#  'round',
#  'ceil',
#  'clip']

# %% [markdown]
# ## Batch Job Processing
#
# OpenEO ArgoWorkflows uses batch jobs for processing. We'll create a job, start it, wait for completion, then retrieve results.

# %% [markdown]
# ### Load and process Sentinel-2 data

# %%
# Load collection using load_stac (pointing to our STAC catalogue)
stac_collection_url = f"{stac_api_url}/collections/{collection_id}"

cube = connection.load_stac(
    url=stac_collection_url,
    temporal_extent=temporal_extent,
    spatial_extent=spatial_extent,
    bands=["red", "nir"],
)

# Calculate NDVI
red = cube.band("red")
nir = cube.band("nir")
ndvi = (nir - red) / (nir + red)

# Save result as GTiff
result = ndvi.save_result(format="netCDF")

# %% [markdown]
# ### Create and start the batch job

# %%
job = result.create_job(title="NDVI Iceland")
print(f"Created job: {job.job_id}")
# Out:
# Created job: 3fc1278b-f22f-4071-96dd-db774c163655

# %%
job.start_job()
print(f"Job started: {job.job_id}")
# Out:
# Job started: 3fc1278b-f22f-4071-96dd-db774c163655

# %% [markdown]
# ### Monitor job progress

# %%
def wait_for_job(job, poll_interval=10, timeout=600):
    """Wait for a job to complete, polling at the specified interval."""
    start_time = time.time()
    
    while True:
        status = job.status()
        print(f"Job {job.job_id}: {status}")
        
        if status == "finished":
            print("Job completed successfully!")
            return True
        elif status in ["error", "canceled"]:
            print(f"Job failed with status: {status}")
            # Try to get error details
            job_info = job.describe_job()
            if "message" in job_info:
                print(f"Error message: {job_info['message']}")
            return False
        
        elapsed = time.time() - start_time
        if elapsed > timeout:
            print(f"Timeout after {timeout} seconds")
            return False
        
        time.sleep(poll_interval)

# %%
success = wait_for_job(job, poll_interval=15, timeout=300)
# Out:
# Job 3fc1278b-f22f-4071-96dd-db774c163655: running
# Job 3fc1278b-f22f-4071-96dd-db774c163655: running
# Job 3fc1278b-f22f-4071-96dd-db774c163655: finished
# Job completed successfully!

# %% [markdown]
# ### Download results

# %%
if success:
    results = job.get_results()
    print("Available result files:")
    for asset in results.get_assets():
        print(f"  - {asset.name}: {asset.href}")
# Out:
# Failed to parse API error response: [500] 'Internal Server Error' (headers: {'Content-Type': 'text/plain; charset=utf-8', 'Content-Length': '21', 'Connection': 'keep-alive', 'date': 'Thu, 18 Dec 2025 14:38:11 GMT', 'Server': 'APISIX', 'X-APISIX-Upstream-Status': '500', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, PATCH, OPTIONS', 'Access-Control-Max-Age': '5', 'Access-Control-Allow-Headers': 'DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Authorization'})
# Available result files:
# ---------------------------------------------------------------------------
# OpenEoApiPlainError                       Traceback (most recent call last)
# Cell In[16], line 4
#       2 results = job.get_results()
#       3 print("Available result files:")
# ----> 4 for asset in results.get_assets():
#       5     print(f"  - {asset.name}: {asset.href}")
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/job.py:471, in JobResults.get_assets(self)
#     467 """
#     468 Get all assets from the job results.
#     469 """
#     470 # TODO: add arguments to filter on metadata, e.g. to only get assets of type "image/tiff"
# --> 471 metadata = self.get_metadata()
#     472 # API 1.0 style: dictionary mapping filenames to metadata dict (with at least a "href" field)
#     473 assets = metadata.get("assets", {})
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/job.py:459, in JobResults.get_metadata(self, force)
#     457 """Get batch job results metadata (parsed JSON)"""
#     458 if self._results is None or force:
# --> 459     self._results = self._job.connection.get(
#     460         self._job.get_results_metadata_url(), expected_status=200
#     461     ).json()
#     462 return self._results
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:195, in RestApiConnection.get(self, path, params, stream, auth, **kwargs)
#     177 def get(
#     178     self,
#     179     path: str,
#    (...)
#     184     **kwargs,
#     185 ) -> Response:
#     186     """
#     187     Do GET request to REST API.
#     188
#    (...)
#     193     :return: response: Response
#     194     """
# --> 195     return self.request("get", path=path, params=params, stream=stream, auth=auth, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:664, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     657     return super(Connection, self).request(
#     658         method=method, path=path, headers=headers, auth=auth,
#     659         check_error=check_error, expected_status=expected_status, **kwargs,
#     660     )
#     662 try:
#     663     # Initial request attempt
# --> 664     return _request()
#     665 except OpenEoApiError as api_exc:
#     666     if api_exc.http_status_code in {401, 403} and api_exc.code == "TokenInvalid":
#     667         # Auth token expired: can we refresh?
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:657, in Connection.request.<locals>._request()
#     656 def _request():
# --> 657     return super(Connection, self).request(
#     658         method=method, path=path, headers=headers, auth=auth,
#     659         check_error=check_error, expected_status=expected_status, **kwargs,
#     660     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:132, in RestApiConnection.request(self, method, path, params, headers, auth, check_error, expected_status, **kwargs)
#     130 expected_status = ensure_list(expected_status) if expected_status else []
#     131 if check_error and status >= 400 and status not in expected_status:
# --> 132     self._raise_api_error(resp)
#     133 if expected_status and status not in expected_status:
#     134     raise OpenEoRestError(
#     135         "Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     136             m=method.upper(), p=path, s=status, e=expected_status, body=resp.text
#     137         )
#     138     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:175, in RestApiConnection._raise_api_error(self, response)
#     168 if status_code == 502 and "Proxy Error" in text:
#     169     error_message = (
#     170         "Received 502 Proxy Error."
#     171         " This typically happens when a synchronous openEO processing request takes too long and is aborted."
#     172         " Consider using a batch job instead."
#     173     )
# --> 175 raise OpenEoApiPlainError(message=text, http_status_code=status_code, error_message=error_message)
#
# OpenEoApiPlainError: [500] Internal Server Error

# %%
if success:
    # Download all results to a directory
    results.download_files("./openeo-argo-results/")
    print("Results downloaded to ./openeo-argo-results/")

# %% [markdown]
# ### Inspect results

# %%
import glob
import rasterio
from rasterio.plot import show

# Find downloaded GeoTIFF files
tiff_files = glob.glob("./openeo-argo-results/*.tif")
print(f"Found {len(tiff_files)} GeoTIFF files")

if tiff_files:
    # Display the first result
    with rasterio.open(tiff_files[0]) as src:
        fig, ax = pyplot.subplots(dpi=75, figsize=(8, 8))
        show(src, ax=ax, cmap="RdYlGn", vmin=-1, vmax=1)
        ax.set_title("NDVI - Iceland (Sentinel-2)")

# %% [markdown]
# ### List all jobs

# %%
jobs = connection.list_jobs()
print(f"Total jobs: {len(jobs)}")
for j in jobs[:5]:
    print(f"  - {j.get('id')}: {j.get('status')} - {j.get('title', 'Untitled')}")
# Out:
# Failed to parse API error response: [500] 'Internal Server Error' (headers: {'Content-Type': 'text/plain; charset=utf-8', 'Content-Length': '21', 'Connection': 'keep-alive', 'date': 'Thu, 18 Dec 2025 14:47:38 GMT', 'Server': 'APISIX', 'X-APISIX-Upstream-Status': '500', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, PATCH, OPTIONS', 'Access-Control-Max-Age': '5', 'Access-Control-Allow-Headers': 'DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Authorization'})
# ---------------------------------------------------------------------------
# OpenEoApiPlainError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 jobs = connection.list_jobs()
#       2 print(f"Total jobs: {len(jobs)}")
#       3 for j in jobs[:5]:
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:909, in Connection.list_jobs(self, limit)
#     893 """
#     894 Lists (batch) jobs metadata of the authenticated user.
#     895
#    (...)
#     905     instead of simple ``List[dict]``.
#     906 """
#     907 # TODO: Parse the result so that Job classes returned?
#     908 # TODO: when pagination is enabled: how to expose link to next page?
# --> 909 resp = self.get("/jobs", params={"limit": limit}, expected_status=200).json()
#     910 return JobListingResponse(response_data=resp)
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:195, in RestApiConnection.get(self, path, params, stream, auth, **kwargs)
#     177 def get(
#     178     self,
#     179     path: str,
#    (...)
#     184     **kwargs,
#     185 ) -> Response:
#     186     """
#     187     Do GET request to REST API.
#     188
#    (...)
#     193     :return: response: Response
#     194     """
# --> 195     return self.request("get", path=path, params=params, stream=stream, auth=auth, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:664, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     657     return super(Connection, self).request(
#     658         method=method, path=path, headers=headers, auth=auth,
#     659         check_error=check_error, expected_status=expected_status, **kwargs,
#     660     )
#     662 try:
#     663     # Initial request attempt
# --> 664     return _request()
#     665 except OpenEoApiError as api_exc:
#     666     if api_exc.http_status_code in {401, 403} and api_exc.code == "TokenInvalid":
#     667         # Auth token expired: can we refresh?
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:657, in Connection.request.<locals>._request()
#     656 def _request():
# --> 657     return super(Connection, self).request(
#     658         method=method, path=path, headers=headers, auth=auth,
#     659         check_error=check_error, expected_status=expected_status, **kwargs,
#     660     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:132, in RestApiConnection.request(self, method, path, params, headers, auth, check_error, expected_status, **kwargs)
#     130 expected_status = ensure_list(expected_status) if expected_status else []
#     131 if check_error and status >= 400 and status not in expected_status:
# --> 132     self._raise_api_error(resp)
#     133 if expected_status and status not in expected_status:
#     134     raise OpenEoRestError(
#     135         "Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     136             m=method.upper(), p=path, s=status, e=expected_status, body=resp.text
#     137         )
#     138     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/_connection.py:175, in RestApiConnection._raise_api_error(self, response)
#     168 if status_code == 502 and "Proxy Error" in text:
#     169     error_message = (
#     170         "Received 502 Proxy Error."
#     171         " This typically happens when a synchronous openEO processing request takes too long and is aborted."
#     172         " Consider using a batch job instead."
#     173     )
# --> 175 raise OpenEoApiPlainError(message=text, http_status_code=status_code, error_message=error_message)
#
# OpenEoApiPlainError: [500] Internal Server Error

# %%
if test_results:
    for test, result in test_results.items():
        print(f"{test}: {result['status']} - {result['message']}")
    json.dump(test_results, open(log_output_file, "w"), indent=2)
