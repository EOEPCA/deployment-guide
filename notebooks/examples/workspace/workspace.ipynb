# %% [markdown]
# # Workspace Demonstration
#
# The **Workspace** Building Block provisions a self-service environment - object storage, an interactive Datalab (VS Code + Terminal, backed by a dedicated vCluster), and Keycloak-based access control - all declaratively via a single REST API. This notebook walks through creating a workspace, using its storage, and starting an interactive session.

# %% [markdown]
# ## Setup

# %%
import os
import sys
import time
import json
import requests
import boto3
from IPython.display import JSON, Javascript

sys.path.append('../')
from modules.helpers import get_access_token, load_eoepca_state, test_cell, test_results

# %% [markdown]
# Load `eoepca state` environment

# %%
load_eoepca_state()

# %%
platform_domain = os.environ.get("INGRESS_HOST")
workspace_api_endpoint = f"{os.environ.get('HTTP_SCHEME')}://workspace-api.{platform_domain}"

admin_user = os.environ.get("KEYCLOAK_TEST_ADMIN")
admin_password = os.environ.get("KEYCLOAK_TEST_PASSWORD")

demo_user = os.environ.get("KEYCLOAK_TEST_USER")
demo_password = os.environ.get("KEYCLOAK_TEST_PASSWORD")

workspace_api_client_id = os.environ.get("WORKSPACE_API_CLIENT_ID")
workspace_api_client_secret = os.environ.get("WORKSPACE_API_CLIENT_SECRET")

workspace_name = f"ws-{demo_user}"

log_output_file = "workspace_log.json"

# %%
print(f"Parameters:\n"
f"Platform domain: {platform_domain}\n"
f"Workspace API endpoint: {workspace_api_endpoint}\n"
f"Demo user: {demo_user}\n"
f"Workspace name: {workspace_name}")

# %% [markdown]
# ## Helper for authenticated Workspace API sessions

# %%
sessions = {}
def get_session(username, password):
    if username not in sessions:
        sessions[username] = requests.Session()
    token = get_access_token(username, password, workspace_api_client_id, workspace_api_client_secret)
    sessions[username].headers.update({"Authorization": f"Bearer {token}"})
    return sessions[username]

# %% [markdown]
# ## Check the Workspace API is Reachable
#
# The `/probe` endpoint requires no authentication and is used for liveness checks.

# %%
# workspace_api_reachable
response = requests.get(f"{workspace_api_endpoint}/probe")
print(f"Probe response: {response.status_code}")
assert response.status_code == 200

# %% [markdown]
# ## Create a Workspace
#
# Any authenticated user in the realm may create a workspace on behalf of another user - here `eoepcaadmin` creates one owned by `eoepcauser`.
#
# Remove any pre-existing workspace of the same name first, so the notebook can be re-run cleanly.

# %%
cleanup_response = get_session(admin_user, admin_password).delete(f"{workspace_api_endpoint}/workspaces/{workspace_name}")
if cleanup_response.status_code == 204:
    print(f"Removed pre-existing workspace '{workspace_name}'")
    time.sleep(5)

# %%
# create_workspace
response = get_session(admin_user, admin_password).post(
    f"{workspace_api_endpoint}/workspaces",
    json={"preferred_name": demo_user, "default_owner": demo_user},
)
print(f"Create workspace response: {response.status_code} {response.text}")
assert response.status_code == 201
assert response.json()["name"] == workspace_name

# %% [markdown]
# ## Wait for Provisioning
#
# Workspace creation triggers Crossplane to declaratively provision a dedicated namespace, an S3 bucket (`Storage` CR) and a Datalab environment (`Datalab` CR). Poll the workspace until it reports `ready`.
#
# The owner (`eoepcauser`) must fetch a *fresh* token here - the pipeline adds them to the workspace's Keycloak groups as part of provisioning, and only a newly-issued token carries that `groups` claim.

# %%
# workspace_provisioned
deadline = time.time() + 180
status = None
while time.time() < deadline:
    details = get_session(demo_user, demo_password).get(f"{workspace_api_endpoint}/workspaces/{workspace_name}").json()
    status = details.get("status")
    if status == "ready":
        break
    time.sleep(5)
print(f"Workspace status: {status}")
assert status == "ready", f"Workspace did not become ready in time (last status: {status})"

# %% [markdown]
# ## Workspace Details
#
# The owner can view full details, including S3 credentials and Datalab membership/sessions.

# %%
details = get_session(demo_user, demo_password).get(f"{workspace_api_endpoint}/workspaces/{workspace_name}").json()
JSON(details, expanded=True)

# %% [markdown]
# ## S3 Object Storage Access
#
# Every workspace gets a dedicated S3 bucket with its own credentials, usable with any S3-compatible client such as `boto3` or `s3cmd`.

# %%
creds = details["storage"]["credentials"]
s3 = boto3.client(
    "s3",
    endpoint_url=creds["endpoint"],
    aws_access_key_id=creds["access"],
    aws_secret_access_key=creds["secret"],
    region_name=creds["region"],
)

# %%
# s3_bucket_access
bucket = creds["bucketname"]
s3.put_object(Bucket=bucket, Key="hello.txt", Body=b"Hello EOEPCA Workspace")
objects = [o["Key"] for o in s3.list_objects_v2(Bucket=bucket).get("Contents", [])]
print(f"Objects in '{bucket}': {objects}")
assert "hello.txt" in objects
_ = s3.delete_object(Bucket=bucket, Key="hello.txt")

# %% [markdown]
# ## Start a Datalab Session
#
# The default Datalab session starts stopped. Starting it provisions a VS Code / Terminal environment backed by a dedicated vCluster - this can take a couple of minutes.

# %%
# datalab_session_started
response = get_session(demo_user, demo_password).patch(
    f"{workspace_api_endpoint}/workspaces/{workspace_name}/sessions/default",
    json={"state": "started"},
)
assert response.status_code == 202

deadline = time.time() + 180
session_ready = False
session_url = None
while time.time() < deadline:
    details = get_session(demo_user, demo_password).get(f"{workspace_api_endpoint}/workspaces/{workspace_name}").json()
    session = next(s for s in details["datalab"]["sessions"] if s["name"] == "default")
    session_ready = session.get("ready", False)
    session_url = session.get("url")
    if session_ready:
        break
    time.sleep(5)
print(f"Session ready: {session_ready}, URL: {session_url}")
assert session_ready, "Datalab session did not become ready in time"

# The API's own "ready" flag reflects the Datalab CR's status, not whether the
# session's ingress route actually resolves - confirm the URL itself responds
# before trusting it (a route/plugin-sync failure can leave "ready" true while
# the URL 404s).
deadline = time.time() + 90
session_status_code = None
while time.time() < deadline:
    session_status_code = requests.get(session_url, allow_redirects=True).status_code
    if session_status_code not in (404, 502, 503):
        break
    time.sleep(5)
print(f"Session URL status: {session_status_code}")
assert session_status_code not in (404, 502, 503), \
    f"Datalab session URL not reachable (status {session_status_code}): {session_url}"

# %% [markdown]
# ## Open the Datalab Session
#
# Open the session in a browser (login as `eoepcauser`) and explore:
#
# * **Terminal** - a shell with `kubectl`/`helm` pre-installed, pointed at the workspace's own vCluster (try `kubectl get pods -A`) and at the S3 bucket (try `aws s3 ls`).
# * **Editor** - a VS Code-style IDE with the same environment, reachable via its own in-built terminal.
# * **Data** - a file browser onto the object storage bucket.

# %%
print(f"Datalab session URL: {session_url}")
Javascript(f'window.open("{session_url}");')

# %% [markdown]
# ## Delete the Workspace
#
# Deleting a workspace tears down its namespace, storage, and Datalab/vCluster resources. Any authenticated user may delete a workspace, not just its owner.

# %%
# workspace_deleted
response = get_session(admin_user, admin_password).delete(f"{workspace_api_endpoint}/workspaces/{workspace_name}")
print(f"Delete workspace response: {response.status_code}")
assert response.status_code == 204

# %%
if test_results:
    for test, result in test_results.items():
        print(f"{test}: {result['status']} - {result['message']}")
    json.dump(test_results, open(log_output_file, "w"), indent=2)
